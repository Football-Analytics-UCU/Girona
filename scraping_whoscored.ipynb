# %%
import re
import json
import pandas as pd

# %%
def extract_json_from_html(html_path, save_output=False):
    html_file = open(html_path, 'r')
    html = html_file.read()
    html_file.close()
    regex_pattern = r'(?<=require\.config\.params\["args"\].=.)[\s\S]*?;'
    data_txt = re.findall(regex_pattern, html)[0]

    # add quotations for json parser
    data_txt = data_txt.replace('matchId', '"matchId"')
    data_txt = data_txt.replace('matchCentreData', '"matchCentreData"')
    data_txt = data_txt.replace('matchCentreEventTypeJson', '"matchCentreEventTypeJson"')
    data_txt = data_txt.replace('formationIdNameMappings', '"formationIdNameMappings"')
    data_txt = data_txt.replace('};', '}')

    data_dict = json.loads(data_txt)
    if save_output:
        # save json data
        with open(f"{html_path[:-5]}.json", "w") as output_file:
            output_file.write(data_txt)

    return data_dict

# %% [markdown]
# To avoid using Selenium, just copy-paste HTML page into `./data/WhoScored/match_{id}.html` once loaded and switched to `Match Centre` -> `Chalkboard` tab:
#
# https://www.whoscored.com/Matches/1734731/Live/Spain-LaLiga-2023-2024-Barcelona-Girona

# %%
data_dict = extract_json_from_html("./data/WhoScored/match_1734731.html", save_output=True)
data_dict.keys()
# Out:
# dict_keys(['matchId', 'matchCentreData', 'matchCentreEventTypeJson', 'formationIdNameMappings'])

# %%
def extract_data_from_dict(data):
    # load data from json
    event_types_json = data["matchCentreEventTypeJson"]
    formation_mappings = data["formationIdNameMappings"]
    events_dict = data["matchCentreData"]["events"]
    teams_dict = {data["matchCentreData"]['home']['teamId']: data["matchCentreData"]['home']['name'],
                  data["matchCentreData"]['away']['teamId']: data["matchCentreData"]['away']['name']}
    players_dict = data["matchCentreData"]["playerIdNameDictionary"]
    # create players dataframe
    players_home_df = pd.DataFrame(data["matchCentreData"]['home']['players'])
    players_home_df["teamId"] = data["matchCentreData"]['home']['teamId']
    players_away_df = pd.DataFrame(data["matchCentreData"]['away']['players'])
    players_away_df["teamId"] = data["matchCentreData"]['away']['teamId']
    players_df = pd.concat([players_home_df, players_away_df])
    players_ids = data["matchCentreData"]["playerIdNameDictionary"]
    return events_dict, players_df, teams_dict

# %%
events_dict, players_df, teams_dict = extract_data_from_dict(data_dict)
len(events_dict)
# Out:
# 1638

# %%
teams_dict
# Out:
# {65: 'Barcelona', 2783: 'Girona'}

# %%
home_team_id = 2783
away_team_id = 65
# home_team_id, away_team_id

# %%
def get_passes_df(events_dict):
    df = pd.DataFrame(events_dict)
    df['eventType'] = df.apply(lambda row: row['type']['displayName'], axis=1)
    df['outcomeType'] = df.apply(lambda row: row['outcomeType']['displayName'], axis=1)

    # create receiver column based on the next event
    # this will be correct only for successfull passes
    df["receiver"] = df["playerId"].shift(-1)

    # filter only passes
    passes_ids = df.index[df['eventType'] == 'Pass']
    df_passes = df.loc[
        passes_ids, ["id", "x", "y", "endX", "endY", "teamId", "playerId", "receiver", "eventType", "outcomeType"]]

    return df_passes

# %%
passes_df = get_passes_df(events_dict)
passes_df
# Out:
#                 id     x     y  endX  endY  teamId  playerId  receiver  \
# 2     2.627665e+09  49.8  50.1  35.6  28.4      65  402197.0  301019.0
# 3     2.627665e+09  35.6  28.4  72.0  58.7      65  301019.0   29400.0
# 6     2.627665e+09  73.8  58.1  91.8  60.0      65   29400.0  104732.0
# 8     2.627665e+09  13.5  35.3  26.5  22.4    2783  104732.0  372473.0
# 9     2.627665e+09  26.5  22.4  30.3   6.3    2783  372473.0  421975.0
# ...            ...   ...   ...   ...   ...     ...       ...       ...
# 1603  2.627708e+09  80.1  72.8  79.8  62.4      65  422938.0  445345.0
# 1606  2.627708e+09   9.5  83.6  12.8  81.5    2783  395788.0  480249.0
# 1620  2.627709e+09  99.6   0.4  88.0  14.6      65  480249.0  279423.0
# 1621  2.627709e+09  86.8  18.6  91.3  48.7      65  279423.0   24400.0
# 1628  2.627709e+09  60.2  16.2  58.3  38.6    2783  106895.0  445345.0
#
#      eventType   outcomeType
# 2         Pass    Successful
# 3         Pass    Successful
# 6         Pass  Unsuccessful
# 8         Pass    Successful
# 9         Pass    Successful
# ...        ...           ...
# 1603      Pass  Unsuccessful
# 1606      Pass  Unsuccessful
# 1620      Pass    Successful
# 1621      Pass  Unsuccessful
# 1628      Pass    Successful
#
# [1071 rows x 10 columns]

# %%
def get_passes_between_df(team_id, passes_df, players_df):
    # filter for only team
    print(team_id)
    passes_df = passes_df[passes_df["teamId"] == team_id]

    # add column with first eleven players only
    passes_df = passes_df.merge(players_df[["playerId", "isFirstEleven"]], on='playerId', how='left')
    # filter on first eleven column
    passes_df = passes_df[passes_df['isFirstEleven'] == True]

    # calculate mean positions for players
    average_locs_and_count_df = (passes_df.groupby('playerId')
                                 .agg({'x': ['mean'], 'y': ['mean', 'count']}))
    average_locs_and_count_df.columns = ['x', 'y', 'count']
    average_locs_and_count_df = average_locs_and_count_df.merge(players_df[['playerId', 'name', 'shirtNo', 'position']],
                                                                on='playerId', how='left')
    average_locs_and_count_df = average_locs_and_count_df.set_index('playerId')
    # print(average_locs_and_count_df)

    # calculate the number of passes between each position (using min/ max so we get passes both ways)
    passes_player_ids_df = passes_df.loc[:, ['id', 'playerId', 'receiver', 'teamId']]
    passes_player_ids_df['pos_max'] = (passes_player_ids_df[['playerId', 'receiver']].max(axis='columns'))
    passes_player_ids_df['pos_min'] = (passes_player_ids_df[['playerId', 'receiver']].min(axis='columns'))

    # get passes between each player
    passes_between_df = passes_player_ids_df.groupby(['pos_min', 'pos_max']).id.count().reset_index()
    passes_between_df.rename({'id': 'pass_count'}, axis='columns', inplace=True)

    # add on the location of each player so we have the start and end positions of the lines
    passes_between_df = passes_between_df.merge(average_locs_and_count_df, left_on='pos_min', right_index=True)
    passes_between_df = passes_between_df.merge(average_locs_and_count_df, left_on='pos_max', right_index=True,
                                                suffixes=['', '_end'])
    return passes_between_df, average_locs_and_count_df

# %%
home_passes_between_df, home_average_locs_and_count_df = get_passes_between_df(team_id=home_team_id, passes_df=passes_df, players_df=players_df)
home_passes_between_df
# Out:
# 2783
#       pos_min   pos_max  pass_count          x          y  count  \
# 5     70033.0   92691.0          10  40.765000  80.163333     60
# 6     70033.0  104732.0           6  40.765000  80.163333     60
# 8     70033.0  231125.0           7  40.765000  80.163333     60
# 24   Viktor Tsygankov            8          AMC
# 26       Aleix García           14           MC
# 27       Artem Dovbyk            9           FW
# 29        Eric García           25           DC
# 30        Iván Martín           23           MC
# 31   Miguel Gutiérrez            3          DML
# 32              Sávio           16          AMC
# 33          Yan Couto           20          DMR
# 37       Aleix García           14           MC
# 38       Artem Dovbyk            9           FW
# 41        Eric García           25           DC
# 42        Iván Martín           23           MC
# 44   Miguel Gutiérrez            3          DML
# 45          Yan Couto           20          DMR
# 55       Aleix García           14           MC
# 56       Artem Dovbyk            9           FW
# 57        Eric García           25           DC
# 58        Iván Martín           23           MC
# 60   Miguel Gutiérrez            3          DML
# 61              Sávio           16          AMC
# 62          Yan Couto           20          DMR
# 66       Artem Dovbyk            9           FW
# 70        Eric García           25           DC
# 71        Iván Martín           23           MC
# 73   Miguel Gutiérrez            3          DML
# 74              Sávio           16          AMC
# 75          Yan Couto           20          DMR
# 79        Eric García           25           DC
# 80        Iván Martín           23           MC
# 81   Miguel Gutiérrez            3          DML
# 82              Sávio           16          AMC
# 83          Yan Couto           20          DMR
# 90        Iván Martín           23           MC
# 92   Miguel Gutiérrez            3          DML
# 93          Yan Couto           20          DMR
# 94   Miguel Gutiérrez            3          DML
# 95              Sávio           16          AMC
# 96          Yan Couto           20          DMR
# 98              Sávio           16          AMC
# 99          Yan Couto           20          DMR
# 102         Yan Couto           20          DMR

# %%
away_passes_between_df, away_average_locs_and_count_df = get_passes_between_df(team_id=away_team_id, passes_df=passes_df, players_df=players_df)
away_passes_between_df
# Out:
# 65
#       pos_min   pos_max  pass_count          x          y  count  \
# 2     29400.0   77464.0           2  74.728571  48.585714     14
# 5     29400.0  128967.0           2  74.728571  48.585714     14
# 6     29400.0  130331.0           2  74.728571  48.585714     14
# 7     29400.0  279423.0           5  74.728571  48.585714     14
# 8     29400.0  300447.0           4  74.728571  48.585714     14
# 9     29400.0  301019.0           4  74.728571  48.585714     14
# 10    29400.0  362431.0           3  74.728571  48.585714     14
# 12    29400.0  402197.0           8  74.728571  48.585714     14
# 26    77464.0  128967.0          13  53.650000  52.645238     84
# 27    77464.0  130331.0          27  53.650000  52.645238     84
# 28    77464.0  279423.0          34  53.650000  52.645238     84
# 31    77464.0  300447.0           9  53.650000  52.645238     84
# 32    77464.0  301019.0          12  53.650000  52.645238     84
# 34    77464.0  362431.0           4  53.650000  52.645238     84
# 35    77464.0  367164.0           7  53.650000  52.645238     84
# 38    77464.0  384711.0          16  53.650000  52.645238     84
# 39    77464.0  402197.0          11  53.650000  52.645238     84
# 49   128967.0  130331.0          18  54.862712  82.579661     59
# 51   128967.0  279423.0          13  54.862712  82.579661     59
# 52   128967.0  300447.0           3  54.862712  82.579661     59
# 53   128967.0  301019.0           1  54.862712  82.579661     59
# 55   128967.0  362431.0           9  54.862712  82.579661     59
# 56   128967.0  367164.0           1  54.862712  82.579661     59
# 58   128967.0  384711.0           7  54.862712  82.579661     59
# 60   128967.0  402197.0           6  54.862712  82.579661     59
# 63   130331.0  279423.0          10  43.371429  70.136735     49
# 64   130331.0  362431.0           7  43.371429  70.136735     49
# 66   Andreas Christensen       15       DC  35.220690  41.450000         58
# 67   Andreas Christensen       15       DC  61.102083  34.091667         48
# 69       Frenkie de Jong       21       MC  68.476667  16.430000         30
# 70       Frenkie de Jong       21       MC  50.176667  13.346667         60
# 72       Frenkie de Jong       21       MC  67.795238  62.785714         21
# 73       Frenkie de Jong       21       MC   9.368182  49.268182         22
# 75       Frenkie de Jong       21       MC  35.220690  41.450000         58
# 76       Frenkie de Jong       21       MC  61.102083  34.091667         48
# 86              Raphinha       11      FWR  50.176667  13.346667         60
# 87              Raphinha       11      FWR  67.795238  62.785714         21
# 90              Raphinha       11      FWR  35.220690  41.450000         58
# 92              Raphinha       11      FWR  61.102083  34.091667         48
# 93          Jules Koundé       23       DR  50.176667  13.346667         60
# 94          Jules Koundé       23       DR  67.795238  62.785714         21
# 95          Jules Koundé       23       DR   9.368182  49.268182         22
# 96          Jules Koundé       23       DR  35.220690  41.450000         58
# 99          Jules Koundé       23       DR  61.102083  34.091667         48
# 104           João Félix       14      FWL  35.220690  41.450000         58
# 105           João Félix       14      FWL  61.102083  34.091667         48
# 108           Iñaki Peña       13       GK  35.220690  41.450000         58
# 110           Iñaki Peña       13       GK  61.102083  34.091667         48
# 116        Ronald Araújo        4       DC  35.220690  41.450000         58
# 118        Ronald Araújo        4       DC  61.102083  34.091667         48
#
#                 name_end  shirtNo_end position_end
# 2         Ilkay Gündogan           22           MC
# 5           João Cancelo            2           DL
# 6    Andreas Christensen           15           DC
# 7        Frenkie de Jong           21           MC
# 8               Raphinha           11          FWR
# 9           Jules Koundé           23           DR
# 10            João Félix           14          FWL
# 12                 Pedri            8           MC
# 26          João Cancelo            2           DL
# 27   Andreas Christensen           15           DC
# 28       Frenkie de Jong           21           MC
# 31              Raphinha           11          FWR
# 32          Jules Koundé           23           DR
# 34            João Félix           14          FWL
# 35            Iñaki Peña           13           GK
# 38         Ronald Araújo            4           DC
# 39                 Pedri            8           MC
# 49   Andreas Christensen           15           DC
# 51       Frenkie de Jong           21           MC
# 52              Raphinha           11          FWR
# 53          Jules Koundé           23           DR
# 55            João Félix           14          FWL
# 56            Iñaki Peña           13           GK
# 58         Ronald Araújo            4           DC
# 60                 Pedri            8           MC
# 63       Frenkie de Jong           21           MC
# 64            João Félix           14          FWL
# 65            Iñaki Peña           13           GK
# 66         Ronald Araújo            4           DC
# 67                 Pedri            8           MC
# 69              Raphinha           11          FWR
# 70          Jules Koundé           23           DR
# 72            João Félix           14          FWL
# 73            Iñaki Peña           13           GK
# 75         Ronald Araújo            4           DC
# 76                 Pedri            8           MC
# 86          Jules Koundé           23           DR
# 87            João Félix           14          FWL
# 90         Ronald Araújo            4           DC
# 92                 Pedri            8           MC
# 93          Jules Koundé           23           DR
# 94            João Félix           14          FWL
# 95            Iñaki Peña           13           GK
# 96         Ronald Araújo            4           DC
# 99                 Pedri            8           MC
# 104        Ronald Araújo            4           DC
# 105                Pedri            8           MC
# 108        Ronald Araújo            4           DC
# 110                Pedri            8           MC
# 116        Ronald Araújo            4           DC
# 118                Pedri            8           MC
