# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import re

# %%
# Entering Barcelona vs Girona match link
link = "https://understat.com/match/22835"
res = requests.get(link)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')
# Get the shotsData, it's the second script executed in order
strings = scripts[1].string 
# Getting rid of unnecessary characters from json data
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
df_h = pd.DataFrame(data['h'])
df_a = pd.DataFrame(data['a'])
df = pd.concat([df_h, df_a], ignore_index=True)

# %%
df
# Out:
#         id minute       result                   X                    Y  \
# 0   553813      4  MissedShots                0.92    0.624000015258789
# 1   553815      6  BlockedShot  0.9540000152587891  0.41200000762939454
# 2   553817     14  BlockedShot  0.8719999694824219  0.39099998474121095
# 3   553818     17    SavedShot  0.9690000152587891   0.4879999923706055
# 4   553819     18         Goal  0.9319999694824219    0.514000015258789
# 5   553820     20  MissedShots  0.8640000152587891                0.305
# 6   553823     28  BlockedShot  0.8719999694824219    0.595999984741211
# 7   553824     29  BlockedShot  0.8340000152587891   0.5940000152587891
# 8   553825     31    SavedShot  0.9640000152587891    0.600999984741211
# 9   553826     38    SavedShot  0.7340000152587891                 0.54
# 10  553829     47    SavedShot  0.9519999694824218   0.5679999923706055
# 11  553830     48  MissedShots  0.9269999694824219    0.605999984741211
# ...

# %%
# Save DataFrame to a JSON file
df.to_json('shot_data.json', orient='records')

# %%
# Entering Barcelona vs Girona match link
link = "https://understat.com/match/22835"
res = requests.get(link)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')
# Get the Rosters data, it's the third script executed in order
strings = scripts[2].string 
# Getting rid of unnecessary characters from json data
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
df = pd.DataFrame(data['a']).T
df
# Out:
#             id goals own_goals shots                   xG time player_id  \
# 629792  629792     0         0     0                    0   90       973
# 629795  629795     0         0     0                    0   90      8045
# 629793  629793     0         0     0                    0   90       548
# 629794  629794     0         0     1   0.0927460566163063   90      1857
# 629796  629796     0         0     1  0.04972017928957939   81     10946
# 629797  629797     1         0     3  0.21838276088237762   90      8513
# 629798  629798     0         0     0                    0   90      1055
# 629799  629799     0         0     0                    0   90      7529
# 629800  629800     0         0     1   0.4002688229084015   90     11735
# 629801  629801     0         0     2   0.1452057808637619   81     11322
# 629802  629802     1         0     2   0.5761622786521912   76     11736
# 629803  629803     0         0     2    0.629919707775116    1     12046
# ...

# %%
# Save DataFrame to a JSON file
df.to_json('rosters_data.json', orient='records')

# %%
response = requests.get('https://understat.com/match/22835')
match_info = re.search("match_info\s+=\s+JSON.parse\('([^']+)", response.text)
decoded_string = bytes(match_info.groups()[0], 'utf-8').decode('unicode_escape')
matchObj = json.loads(decoded_string)
df = pd.DataFrame(pd.Series(matchObj))
df
# Out:
#                                   0
# id                            22835
# fid                         1734731
# h                               148
# a                               223
# date            2023-12-10 20:00:00
# league_id                         4
# season                         2023
# h_goals                           2
# a_goals                           4
# team_h                    Barcelona
# team_a                       Girona
# h_xg                        4.25448
# a_xg                        2.93797
# h_w                          0.6548
# h_d                          0.1523
# h_l                          0.1929
# league                      La liga
# h_shot                           31
# a_shot                           15
# h_shotOnTarget                   11
# a_shotOnTarget                    7
# h_deep                           20
# a_deep                           11
# a_ppda                      16.0588
# h_ppda                      19.0000

# %%
# Save DataFrame to a JSON file
df.to_json('match_stats.json', orient='records')

# %%
# Entering Artem Dovbyk ID link
link = "https://understat.com/player/11736"
res = requests.get(link)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')
# Get the grouped stats data, it's the second script executed in order
strings = scripts[1].string

# %%
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
df = pd.DataFrame(data['season'])
df
# Out:
#   position games goals shots  time                 xG assists  \
# 0      Sub    19    11    45  1228  8.790441047400236       5
#
#                    xA key_passes season    team yellow red npg  \
# 0  3.5160213513299823         13   2023  Girona      1   0   8
#
#                 npxG            xGChain           xGBuildup
# 0  7.303885828703642  9.930963471531868  1.9230831749737263

# %%
# Save DataFrame to a JSON file
df.to_json('players_grouped_stats.json', orient='records')

# %%
df = pd.DataFrame(data['shotTypes'])
df
# Out:
#                                                         2023
# Head       {'shotTypes': 'Head', 'season': '2023', 'goals...
# LeftFoot   {'shotTypes': 'LeftFoot', 'season': '2023', 'g...
# RightFoot  {'shotTypes': 'RightFoot', 'season': '2023', '...

# %%
df['2023'].apply(pd.Series)
# Out:
#            shotTypes season goals shots                   xG assists  \
# Head            Head   2023     4    18    2.636397410184145       0
# LeftFoot    LeftFoot   2023     7    25    6.031104730442166       2
# RightFoot  RightFoot   2023     0     2  0.12293901666998863       3
#
#           key_passes                  xA npg                 npxG
# Head               0                   0   4    2.636397410184145
# LeftFoot           6  1.3796188421547413   4    4.544549511745572
# RightFoot          7   2.136402583681047   0  0.12293901666998863

# %%
# Save DataFrame to a JSON file
df.to_json('players_goal_stats.json', orient='records')

# %%
# Entering Artem Dovbyk ID link
link = "https://understat.com/player/11736"
res = requests.get(link)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')
# Get the grouped stats data, it's the second script executed in order
strings = scripts[3].string
# Getting rid of unnecessary characters from json data
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
df = pd.DataFrame(data)
df
# Out:
#         id minute       result                   X                    Y  \
# 0   532183     71         Goal  0.9730000305175781   0.5570000076293945
# 1   533996     91    SavedShot  0.8819999694824219                0.635
# 2   535146     72  MissedShots  0.6790000152587891   0.4809999847412109
# 3   535148     84  MissedShots   0.970999984741211    0.585999984741211
# 4   536732     79  MissedShots   0.884000015258789                0.705
# 5   536734     86    SavedShot  0.8080000305175781   0.5029999923706054
# 6   538701      2  MissedShots  0.9230000305175782                 0.74
# 7   538712     59  BlockedShot  0.7280000305175781  0.41200000762939454
# 8   538869     11  MissedShots                0.87  0.43099998474121093
# 9   538874     19    SavedShot  0.9640000152587891                0.625
# 10  538875     21  MissedShots  0.9069999694824219  0.49599998474121093
# 11  538877     32         Goal               0.885                  0.5
# ...

# %%
# Save DataFrame to a JSON file
df.to_json('players_shoot_stats.json', orient='records')

# %%
# Entering Artem Dovbyk ID link
link = "https://understat.com/player/11736"
res = requests.get(link)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')
# Get the grouped stats data, it's the second script executed in order
strings = scripts[4].string # number 4 script and fifth executable 
# Getting rid of unnecessary characters from json data
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
df = pd.DataFrame(data)
df
# Out:
#    goals shots                    xG time position          h_team  \
# 0      0     0                     0   71       FW         Almeria
# 1      0     2   0.49715057015419006   72       FW          Girona
# 2      1     1    0.7432776093482971   70       FW      Real Betis
# 3      2     4                     0   90       FW          Girona
# 4      1     2    0.5761622786521912   76       FW       Barcelona
# 5      0     1  0.060879383236169815   90       FW          Girona
# 6      1     7    1.9443042278289795   83       FW  Rayo Vallecano
# 7      1     4    0.8837571740150452   87       FW         Osasuna
# 8      0     2   0.15992581844329834   76       FW          Girona
# 9      2     3   0.23668920993804932   72       FW          Girona
# 10     0     0                     0   82       FW           Cadiz
# 11     0     1   0.04403261840343475   64       FW          Girona
# 12     1     6    1.1807258129119873   70       FW      Villarreal
# ...

# %%
# Save DataFrame to a JSON file
df.to_json('player_match_data.json', orient='records')

# %%
# Entering Artem Dovbyk ID link
link = "https://understat.com/player/11736"
res = requests.get(link)
soup = BeautifulSoup(res.content,'lxml')
scripts = soup.find_all('script')
# Get the grouped stats data, it's the second script executed in order
strings = scripts[2].string # number 4 script and fifth executable 
# Getting rid of unnecessary characters from json data
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')
data = json.loads(json_data)

# %%
df = pd.DataFrame(data['FW']).T
df
# Out:
#                  min       max       avg
# goals       0.001100  0.012600  0.004200
# xG          0.001728  0.012082  0.004155
# shots       0.015000  0.073700  0.028000
# assists     0.000000  0.004800  0.001400
# xA          0.000264  0.005382  0.001316
# key_passes  0.003600  0.030900  0.012000
# xGChain     0.002727  0.016914  0.005338
# xGBuildup   0.000243  0.006713  0.001318

# %%
# Save DataFrame to a JSON file
df.to_json('radar_data.json', orient='records')
